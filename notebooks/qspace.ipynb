# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(1, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 2, alpha_l, 1, 4)

rblock = qspace.RBlock(qspec)
rblock_out = qspace.RBlock(qspec, build=False)
rblock_out.invoke(rblock.bind(a = rblock_out._a_reg, b = rblock_out._b_reg))
rblock_out.circuit.barrier()
rblock_out.build_circuit()
dir="output/diagrams/"
qstyle={"dpi": 300, "name":"clifford"}
rblock_out.circuit.draw(filename=dir+"R.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(1, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

pablock = qspace.KBlock(qspec)
pa_out = qspace.KBlock(qspec, build=False)
pa_out.invoke(pablock.bind(a = pa_out._a_reg))
pa_out.circuit.barrier()
pa_out.build_circuit()
pa_out.circuit.draw(filename=dir+"K.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(1, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

pbblock = qspace.LogLBlock(qspec)
pb_out = qspace.LogLBlock(qspec, build=False)
pb_out.invoke(pbblock.bind(b = pb_out._b_reg))
pb_out.circuit.barrier()
pb_out.build_circuit()
pb_out.circuit.draw(filename=dir+"logL.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(1, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

bparblock = qspace.BParallelBlock(qspec)
bpar_out = qspace.BParallelBlock(qspec, build=False)
bpar_out.invoke(bparblock.bind(a = bpar_out._a_reg, b = bpar_out._b_reg))
bpar_out.circuit.barrier()
bpar_out.build_circuit()
bpar_out.circuit.draw(filename=dir+"B_par.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

bserblock = qspace.BSerialBlock(qspec)
bser_out = qspace.BSerialBlock(qspec, build=False)
bser_out.invoke(bserblock.bind(a = bser_out._a_reg, b2=bser_out._b2_reg, b1_regs=bser_out._b1_regs))
bser_out.circuit.barrier()
bser_out.build_circuit()
bser_out.circuit.draw(filename=dir+"B_ser.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

hodblock = qspace.HodBlock(qspec)
hod_out = qspace.HodBlock(qspec, build=False)
hod_out.invoke(hodblock.bind(b=hod_out._b_reg, i=hod_out._i_reg))
hod_out.circuit.barrier()
hod_out.build_circuit()
hod_out.circuit.draw(filename=dir+"H_od.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

hxyzblock = qspace.HodxyzBlock(qspec)
hxyz_out = qspace.HodxyzBlock(qspec, build=False)
hxyz_out.invoke(hxyzblock.bind(b2=hxyz_out._b2_reg, b1_regs=hxyz_out._b1_regs, i_regs=hxyz_out._i_regs))
hxyz_out.circuit.barrier()
hxyz_out.build_circuit()
hxyz_out.circuit.draw(filename=dir+"H_od_xyz.png", style=qstyle)

# %% [markdown]
# ## W parallel block

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

wparblock = qspace.WParallelBlock(qspec)
wpar_out = qspace.WParallelBlock(qspec, build=False)
wpar_out.invoke(wparblock.bind(a=wpar_out._a_reg, b=wpar_out._b_reg, i=wpar_out._i_reg))
wpar_out.circuit.barrier()
wpar_out.build_circuit()
wpar_out.circuit.draw(filename=dir+"W_par.png", style=qstyle)

# %% [markdown]
# ## W serial block

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function
import logging

logger = logging.getLogger(__name__)


wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

logger.info("start")
wserblock = qspace.WSerialBlock(qspec)
logger.info("build1")
wser_out = qspace.WSerialBlock(qspec, build=False)
logger.info("build2")
wser_out.invoke(wserblock.bind(a=wser_out._a_reg, b2=wser_out._b2_reg, b1_regs=wser_out._b1_regs, i_regs=wser_out._i_regs))
logger.info("invoke")
wser_out.circuit.barrier()
wser_out.build_circuit()
wser_out.circuit.draw(filename=dir+"W_ser.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)

apar_block = qspace.AParallelBlock(qspec)
apar_out = qspace.AParallelBlock(qspec, build=False)
apar_out.invoke(apar_block.bind(b=apar_out._b_reg, a=apar_out._a_reg, i=apar_out._i_reg))
apar_out.circuit.barrier()
apar_out.build_circuit()
apar_out.circuit.draw(filename=dir+"A_par.png", style=qstyle)

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(3, 3, 2.0, 1, 1, 0)
alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 2, alpha_l, 1, 4)

aser_block = qspace.ASerialBlock(qspec)
aser_out = qspace.ASerialBlock(qspec, build=False)
aser_out.invoke(aser_block.bind(b2=aser_out._b2_reg, a=aser_out._a_reg, b1_regs=aser_out._b1_regs, i_regs=aser_out._i_regs))
aser_out.circuit.barrier()
aser_out.build_circuit()
aser_out.circuit.draw(filename=dir+"A_ser.png", style=qstyle, scale=0.6)

# %% [markdown]
# # full time evolution circuit

# %%
from crsq.blocks.time_evolution import qspace
from crsq.blocks import time_evolution, antisymmetrization, discretization, energy_initialization, firstq, hamiltonian, time_evolution, wave_function

wfr_spec = wave_function.WaveFunctionRegisterSpec(2, 3, 2.0, 2, 1, 0)
ham_spec = hamiltonian.HamiltonianSpec(wfr_spec, [{"mass": 1680.0, "charge": 1.0}])
asy_spec = antisymmetrization.AntisymmetrizationSpec(wfr_spec, 3)
disc_spec = discretization.DiscretizationSpec(0.1)
evo_spec = time_evolution.TimeEvolutionSpec(ham_spec, disc_spec, 1, 1, time_evolution.SUZUKI_TROTTER)
eorbs = wave_function.make_test_elec_orbitals(wfr_spec, 4)
norbs = wave_function.make_test_nucl_orbitals(wfr_spec, 4)
ene_spec = energy_initialization.EnergyConfigurationSpec([0.1,0.1,0.2,0.2], eorbs, norbs)

alpha_l = [1/4, 1/4, 1/4, 1/4]
qspec = qspace.QSpaceTEVSpec(wfr_spec, 4, alpha_l, 1, 4)


qtev_out = qspace.QSpaceMethodBlock(qspec, evo_spec, ene_spec, asy_spec, build = False)
qtev_block = qspace.QSpaceMethodBlock(qspec, evo_spec, ene_spec, asy_spec)
qtev_out.invoke(qtev_block.bind(
    eregs=qtev_out._e_index_regs,
    nregs=qtev_out._n_index_regs,
    shuffle=qtev_out._shuffle,
    slater_indices=qtev_out._slater_indices,
    p=qtev_out._energy_configuration_reg), 
    invoke_as_instruction=True)


qtev_out.circuit.barrier()
qtev_out.build_circuit()
dir="output/diagrams/"
qstyle={"dpi": 300, "name":"clifford"}
qtev_out.circuit.draw(filename=dir+"QspaceTev.png", style=qstyle)
